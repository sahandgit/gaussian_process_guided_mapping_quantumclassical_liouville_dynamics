# %% [markdown]
# # 04 — SE/QCLE/PBME/GP comparison
#
# This notebook documents the comparison workflow after saved runs exist under `runs/P0_10` and `runs/P0_100`.

# %% [markdown]
# ## Full comparison
#
# ```powershell
# gp-mqcld-compare ".\runs" --p0-list 10 100 --R0 -15 --sigma_R 1.0 --dt 0.5 --n_steps 6000 --density-times "0,500,800,1500" --out ".\runs\comparison_P0_10_100"
# ```
#
# ## Fast loading-only check
#
# ```powershell
# gp-mqcld-compare ".\runs" --p0-list 10 100 --dt 0.5 --n_steps 6000 --no-se --no-qcle --out ".\runs\comparison_GP_only_test"
# ```

# %%
# Programmatic command construction.
p0_values = [10, 100]
cmd = 'gp-mqcld-compare ".\\runs" --p0-list ' + ' '.join(map(str, p0_values)) + ' --R0 -15 --sigma_R 1.0 --dt 0.5 --n_steps 6000 --density-times "0,500,800,1500" --out ".\\runs\\comparison_P0_10_100"'
print(cmd)
