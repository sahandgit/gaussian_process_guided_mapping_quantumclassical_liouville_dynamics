# %% [markdown]
# # 00 — Installation and smoke test
#
# This notebook documents the expected installation flow. Run the shell commands in a terminal from the repository root. The smoke test is intentionally tiny and is not a scientific simulation.

# %% [markdown]
# ## Windows PowerShell installation
#
# ```powershell
# python -m venv .venv
# .\.venv\Scripts\Activate.ps1
# python -m pip install --upgrade pip setuptools wheel
# python -m pip install -e ".[dev,notebooks]"
# pytest
# gp-mqcld-smoke
# ```
#
# ## Linux/macOS installation
#
# ```bash
# python -m venv .venv
# source .venv/bin/activate
# python -m pip install --upgrade pip setuptools wheel
# python -m pip install -e ".[dev,notebooks]"
# pytest
# gp-mqcld-smoke
# ```

# %%
# Verify Python-side imports after installation.
import gp_mqcld as gm
print(gm.__version__)
print(gm.TullyModel())

# %%
# Inspect installed command help from inside the notebook.
# On Windows, this runs through the current Python executable environment.
import sys, subprocess
subprocess.run([sys.executable, "-m", "gp_mint_qcle", "--version"], check=True)
subprocess.run(["gp-mqcld-run", "--help"], check=False)

# %% [markdown]
# ## Smoke run
#
# From the terminal, use:
#
# ```powershell
# gp-mqcld-smoke
# ```
#
# This writes a tiny one-step output under `runs/smoke_full/`.
